# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
salaries = pd.read_csv("https://richardson.byu.edu/220/ds_salary.csv")

# %%
salaries.head()
# Out:
#    ...1  work_year experience_level employment_type  \
# 0     0       2020               MI              FT
# 1     1       2020               SE              FT
# 2     2       2020               SE              FT
# 3     3       2020               MI              FT
# 4     4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %% [markdown]
# <h1>1) General Salary Data</h1>
#
# **Histogram of the Salaries**
#
# We decided to start with a histogram of the Salaries, using salary_in_usd  to see the distribution of all the salaries.
# <br>
# We noticed that distribution is right-skewed, which would suggest that the mean, and medium would be between the 100 - 200k range. It would also suggest that salaries on the left side, or less than 200k are going to be common, than higher than 200k.

# %%
plt.hist(salaries['salary_in_usd'])
plt.xlabel('Salary in USD')
plt.ylabel('Frequency')
plt.title('Distribution of Salaries')
plt.show()

# %% [markdown]
# <h1> 2) Effect of Experience on Salary </h1>
#
# **Box Plot of Salary and Experience Level**
# <br>
# Looking at the medians of each box, we noticed a slight increase with each level, and that makes sense in the real world because the entry level or 'en' would make the least, and the executive level would make the most.
#
# We also noticed that the boxes for entry, middle, and senior have similar compact boxes, but the boxes for the executive level are a lot wider. That could suggest that the other levels have less variation due to other factors such as company size but being an executive can vary depending on other factors.
#
# We found it interesting that each level did have outliers. This could suggest that those outliers have to do with specializations within the data science field or that those positions were in high demand when they were hired.

# %%
plt.figure(figsize=(8, 6))
salaries.boxplot(column='salary_in_usd', by='experience_level', vert=False, grid=False)
plt.xlabel('Salary in USD')
plt.ylabel('Experience Level')
plt.title('Salary Distribution by Experience Level')
plt.show()

# %% [markdown]
# <h1> 3) Impact of Company Size on Salary
#
# **Box Plot**
# <br>
# Hello world

# %%
plt.figure(figsize=(8, 6))
salaries.boxplot(column='salary_in_usd', by='company_size', vert=False, grid=False)
plt.xlabel('Salary in USD')
plt.ylabel('Experience Level')
plt.title('Salary Distribution by Experience Level')
plt.show()

# %% [markdown]
# <h1> 4) Job Title Analysis </h1>

# %%
pd.crosstab(salaries["job_title"],salaries["salary_in_usd"])
# Out:
# salary_in_usd                             2859    4000    5409    5679    \
# job_title
# 3D Computer Vision Researcher                  0       0       1       0
# AI Scientist                                   0       0       0       0
# Analytics Engineer                             0       0       0       0
# Applied Data Scientist                         0       0       0       0
# Applied Machine Learning Scientist             0       0       0       0
# BI Data Analyst                                0       0       0       0
# Big Data Architect                             0       0       0       0
# Big Data Engineer                              0       0       0       0
# Business Data Analyst                          0       0       0       0
# Cloud Data Engineer                            0       0       0       0
# Computer Vision Engineer                       0       0       0       0
# Computer Vision Software Engineer              0       0       0       0
# Data Analyst                                   0       0       0       0
# Data Analytics Engineer                        0       0       0       0
# Data Analytics Lead                            0       0       0       0
# Data Analytics Manager                         0       0       0       0
# Data Architect                                 0       0       0       0
# Data Engineer                                  0       1       0       0
# Data Engineering Manager                       0       0       0       0
# Data Science Consultant                        0       0       0       0
# Data Science Engineer                          0       0       0       0
# Data Science Manager                           0       0       0       0
# Data Scientist                                 1       1       0       1
# Data Specialist                                0       0       0       0
# Director of Data Engineering                   0       0       0       0
# Director of Data Science                       0       0       0       0
# ETL Developer                                  0       0       0       0
# Finance Data Analyst                           0       0       0       0
# Financial Data Analyst                         0       0       0       0
# Head of Data                                   0       0       0       0
# Head of Data Science                           0       0       0       0
# Lead Data Analyst                              0       0       0       0
# Lead Data Engineer                             0       0       0       0
# Lead Data Scientist                            0       0       0       0
# Lead Machine Learning Engineer                 0       0       0       0
# ML Engineer                                    0       0       0       0
# Machine Learning Developer                     0       0       0       0
# Machine Learning Engineer                      0       0       0       0
# Machine Learning Infrastructure Engineer       0       0       0       0
# Machine Learning Manager                       0       0       0       0
# Machine Learning Scientist                     0       0       0       0
# Marketing Data Analyst                         0       0       0       0
# NLP Engineer                                   0       0       0       0
# Principal Data Analyst                         0       0       0       0
# Principal Data Engineer                        0       0       0       0
# Principal Data Scientist                       0       0       0       0
# Product Data Analyst                           0       0       0       0
# Research Scientist                             0       0       0       0
# Staff Data Scientist                           0       0       0       0
#
# salary_in_usd                             5707    5882    6072    8000    \
# job_title
# 3D Computer Vision Researcher                  0       0       0       0
# AI Scientist                                   0       0       0       0
# Analytics Engineer                             0       0       0       0
# Applied Data Scientist                         0       0       0       0
# Applied Machine Learning Scientist             0       0       0       0
# BI Data Analyst                                0       0       0       0
# Big Data Architect                             0       0       0       0
# Big Data Engineer                              0       1       0       0
# Business Data Analyst                          0       0       0       0
# Cloud Data Engineer                            0       0       0       0
# Computer Vision Engineer                       0       0       0       0
# Computer Vision Software Engineer              0       0       0       0
# Data Analyst                                   0       0       1       1
# Data Analytics Engineer                        0       0       0       0
# Data Analytics Lead                            0       0       0       0
# Data Analytics Manager                         0       0       0       0
# Data Architect                                 0       0       0       0
# Data Engineer                                  0       0       0       0
# Data Engineering Manager                       0       0       0       0
# Data Science Consultant                        1       0       0       0
# Data Science Engineer                          0       0       0       0
# Data Science Manager                           0       0       0       0
# Data Scientist                                 0       0       0       0
# Data Specialist                                0       0       0       0
# Director of Data Engineering                   0       0       0       0
# Director of Data Science                       0       0       0       0
# ETL Developer                                  0       0       0       0
# Finance Data Analyst                           0       0       0       0
# Financial Data Analyst                         0       0       0       0
# Head of Data                                   0       0       0       0
# Head of Data Science                           0       0       0       0
# Lead Data Analyst                              0       0       0       0
# Lead Data Engineer                             0       0       0       0
# Lead Data Scientist                            0       0       0       0
# Lead Machine Learning Engineer                 0       0       0       0
# ML Engineer                                    0       0       0       0
# Machine Learning Developer                     0       0       0       0
# Machine Learning Engineer                      0       0       0       0
# Machine Learning Infrastructure Engineer       0       0       0       0
# Machine Learning Manager                       0       0       0       0
# Machine Learning Scientist                     0       0       0       0
# Marketing Data Analyst                         0       0       0       0
# NLP Engineer                                   0       0       0       0
# Principal Data Analyst                         0       0       0       0
# Principal Data Engineer                        0       0       0       0
# Principal Data Scientist                       0       0       0       0
# Product Data Analyst                           0       0       1       0
# Research Scientist                             0       0       0       0
# Staff Data Scientist                           0       0       0       0
#
# salary_in_usd                             9272    9466    ...  276000  324000  \
# job_title                                                 ...
# 3D Computer Vision Researcher                  0       0  ...       0       0
# AI Scientist                                   0       0  ...       0       0
# Analytics Engineer                             0       0  ...       0       0
# Applied Data Scientist                         0       0  ...       0       0
# Applied Machine Learning Scientist             0       0  ...       0       0
# BI Data Analyst                                1       0  ...       0       0
# Big Data Architect                             0       0  ...       0       0
# Big Data Engineer                              0       0  ...       0       0
# Business Data Analyst                          0       0  ...       0       0
# Cloud Data Engineer                            0       0  ...       0       0
# Computer Vision Engineer                       0       0  ...       0       0
# Computer Vision Software Engineer              0       0  ...       0       0
# Data Analyst                                   0       0  ...       0       0
# Data Analytics Engineer                        0       0  ...       0       0
# Data Analytics Lead                            0       0  ...       0       0
# Data Analytics Manager                         0       0  ...       0       0
# Data Architect                                 0       0  ...       0       0
# Data Engineer                                  0       0  ...       0       1
# Data Engineering Manager                       0       0  ...       0       0
# Data Science Consultant                        0       0  ...       0       0
# Data Science Engineer                          0       0  ...       0       0
# Data Science Manager                           0       0  ...       0       0
# Data Scientist                                 0       1  ...       0       0
# Data Specialist                                0       0  ...       0       0
# Director of Data Engineering                   0       0  ...       0       0
# Director of Data Science                       0       0  ...       0       0
# ETL Developer                                  0       0  ...       0       0
# Finance Data Analyst                           0       0  ...       0       0
# Financial Data Analyst                         0       0  ...       0       0
# Head of Data                                   0       0  ...       0       0
# Head of Data Science                           0       0  ...       0       0
# Lead Data Analyst                              0       0  ...       0       0
# Lead Data Engineer                             0       0  ...       1       0
# Lead Data Scientist                            0       0  ...       0       0
# Lead Machine Learning Engineer                 0       0  ...       0       0
# ML Engineer                                    0       0  ...       0       0
# Machine Learning Developer                     0       0  ...       0       0
# Machine Learning Engineer                      0       0  ...       0       0
# Machine Learning Infrastructure Engineer       0       0  ...       0       0
# Machine Learning Manager                       0       0  ...       0       0
# Machine Learning Scientist                     0       0  ...       0       0
# Marketing Data Analyst                         0       0  ...       0       0
# NLP Engineer                                   0       0  ...       0       0
# Principal Data Analyst                         0       0  ...       0       0
# Principal Data Engineer                        0       0  ...       0       0
# Principal Data Scientist                       0       0  ...       0       0
# Product Data Analyst                           0       0  ...       0       0
# Research Scientist                             0       0  ...       0       0
# Staff Data Scientist                           0       0  ...       0       0
#
# salary_in_usd                             325000  380000  405000  412000  \
# job_title
# 3D Computer Vision Researcher                  0       0       0       0
# AI Scientist                                   0       0       0       0
# Analytics Engineer                             0       0       0       0
# Applied Data Scientist                         0       1       0       0
# Applied Machine Learning Scientist             0       0       0       0
# BI Data Analyst                                0       0       0       0
# Big Data Architect                             0       0       0       0
# Big Data Engineer                              0       0       0       0
# Business Data Analyst                          0       0       0       0
# Cloud Data Engineer                            0       0       0       0
# Computer Vision Engineer                       0       0       0       0
# Computer Vision Software Engineer              0       0       0       0
# Data Analyst                                   0       0       0       0
# Data Analytics Engineer                        0       0       0       0
# Data Analytics Lead                            0       0       1       0
# Data Analytics Manager                         0       0       0       0
# Data Architect                                 0       0       0       0
# Data Engineer                                  0       0       0       0
# Data Engineering Manager                       0       0       0       0
# Data Science Consultant                        0       0       0       0
# Data Science Engineer                          0       0       0       0
# Data Science Manager                           0       0       0       0
# Data Scientist                                 0       0       0       1
# Data Specialist                                0       0       0       0
# Director of Data Engineering                   0       0       0       0
# Director of Data Science                       1       0       0       0
# ETL Developer                                  0       0       0       0
# Finance Data Analyst                           0       0       0       0
# Financial Data Analyst                         0       0       0       0
# Head of Data                                   0       0       0       0
# Head of Data Science                           0       0       0       0
# Lead Data Analyst                              0       0       0       0
# Lead Data Engineer                             0       0       0       0
# Lead Data Scientist                            0       0       0       0
# Lead Machine Learning Engineer                 0       0       0       0
# ML Engineer                                    0       0       0       0
# Machine Learning Developer                     0       0       0       0
# Machine Learning Engineer                      0       0       0       0
# Machine Learning Infrastructure Engineer       0       0       0       0
# Machine Learning Manager                       0       0       0       0
# Machine Learning Scientist                     0       0       0       0
# Marketing Data Analyst                         0       0       0       0
# NLP Engineer                                   0       0       0       0
# Principal Data Analyst                         0       0       0       0
# Principal Data Engineer                        0       0       0       0
# Principal Data Scientist                       0       0       0       0
# Product Data Analyst                           0       0       0       0
# Research Scientist                             0       0       0       0
# Staff Data Scientist                           0       0       0       0
#
# salary_in_usd                             416000  423000  450000  600000
# job_title
# 3D Computer Vision Researcher                  0       0       0       0
# AI Scientist                                   0       0       0       0
# Analytics Engineer                             0       0       0       0
# Applied Data Scientist                         0       0       0       0
# Applied Machine Learning Scientist             0       1       0       0
# BI Data Analyst                                0       0       0       0
# Big Data Architect                             0       0       0       0
# Big Data Engineer                              0       0       0       0
# Business Data Analyst                          0       0       0       0
# Cloud Data Engineer                            0       0       0       0
# Computer Vision Engineer                       0       0       0       0
# Computer Vision Software Engineer              0       0       0       0
# Data Analyst                                   0       0       0       0
# Data Analytics Engineer                        0       0       0       0
# Data Analytics Lead                            0       0       0       0
# Data Analytics Manager                         0       0       0       0
# Data Architect                                 0       0       0       0
# Data Engineer                                  0       0       0       0
# Data Engineering Manager                       0       0       0       0
# Data Science Consultant                        0       0       0       0
# Data Science Engineer                          0       0       0       0
# Data Science Manager                           0       0       0       0
# Data Scientist                                 0       0       0       0
# Data Specialist                                0       0       0       0
# Director of Data Engineering                   0       0       0       0
# Director of Data Science                       0       0       0       0
# ETL Developer                                  0       0       0       0
# Finance Data Analyst                           0       0       0       0
# Financial Data Analyst                         0       0       1       0
# Head of Data                                   0       0       0       0
# Head of Data Science                           0       0       0       0
# Lead Data Analyst                              0       0       0       0
# Lead Data Engineer                             0       0       0       0
# Lead Data Scientist                            0       0       0       0
# Lead Machine Learning Engineer                 0       0       0       0
# ML Engineer                                    0       0       0       0
# Machine Learning Developer                     0       0       0       0
# Machine Learning Engineer                      0       0       0       0
# Machine Learning Infrastructure Engineer       0       0       0       0
# Machine Learning Manager                       0       0       0       0
# Machine Learning Scientist                     0       0       0       0
# Marketing Data Analyst                         0       0       0       0
# NLP Engineer                                   0       0       0       0
# Principal Data Analyst                         0       0       0       0
# Principal Data Engineer                        0       0       0       1
# Principal Data Scientist                       1       0       0       0
# Product Data Analyst                           0       0       0       0
# Research Scientist                             0       0       1       0
# Staff Data Scientist                           0       0       0       0
#
# [49 rows x 344 columns]

# %% [markdown]
# <h1> 5) Interactions Between Relationships</h1>

# %%
print('hello world')

# %% [markdown]
# <h1> 6) Conclusion </h1>

# %%
print('hello world')
